# %% [markdown]
# <a href="https://colab.research.google.com/github/nishultomar/TensorflowExercises/blob/master/House_Price_Pred_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
housing = pd.read_csv('/content/drive/My Drive/ML Exercise/housing.csv')
housing.head()
# Out:
#    housingMedianAge  totalRooms  ...  medianIncome  medianHouseValue
# 0              41.0       880.0  ...        8.3252          452600.0
# 1              21.0      7099.0  ...        8.3014          358500.0
# 2              52.0      1467.0  ...        7.2574          352100.0
# 3              52.0      1274.0  ...        5.6431          341300.0
# 4              52.0      1627.0  ...        3.8462          342200.0
#
# [5 rows x 7 columns]

# %%
housing.describe().transpose()
# Out:
#                     count           mean  ...           75%          max
# housingMedianAge  20640.0      28.639486  ...      37.00000      52.0000
# totalRooms        20640.0    2635.763081  ...    3148.00000   39320.0000
# totalBedrooms     20640.0     537.898014  ...     647.00000    6445.0000
# population        20640.0    1425.476744  ...    1725.00000   35682.0000
# households        20640.0     499.539680  ...     605.00000    6082.0000
# medianIncome      20640.0       3.870671  ...       4.74325      15.0001
# medianHouseValue  20640.0  206855.816909  ...  264725.00000  500001.0000
#
# [7 rows x 8 columns]

# %%
x_data = housing.drop('medianHouseValue',axis=1)

# %%
y_val = housing["medianHouseValue"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, x_test, Y_train, y_test = train_test_split(x_data,y_val,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_train = pd.DataFrame(data = scaler.transform(X_train),columns=X_train.columns, index = X_train.index)
X_train.head()
# Out:
#       housingMedianAge  totalRooms  ...  households  medianIncome
# 6761          0.352941    0.069688  ...    0.115442      0.142508
# 3010          0.607843    0.011242  ...    0.014142      0.045027
# 7812          0.666667    0.025230  ...    0.030258      0.212866
# 8480          0.666667    0.032530  ...    0.030094      0.298651
# 1051          0.294118    0.031919  ...    0.034863      0.272631
#
# [5 rows x 6 columns]

# %%
x_test = pd.DataFrame(scaler.transform(x_test),columns=x_test.columns, index = x_test.index)
x_test.head()
# Out:
#        housingMedianAge  totalRooms  ...  households  medianIncome
# 16086          0.686275    0.046264  ...    0.048841      0.353133
# 8816           0.705882    0.027417  ...    0.023187      0.770182
# 7175           0.901961    0.032326  ...    0.042592      0.133626
# 16714          0.313725    0.043212  ...    0.048018      0.263576
# 14491          0.411765    0.088433  ...    0.072192      0.660046
#
# [5 rows x 6 columns]

# %%
housing.columns
# Out:
# Index(['housingMedianAge', 'totalRooms', 'totalBedrooms', 'population',
#        'households', 'medianIncome', 'medianHouseValue'],
#       dtype='object')

# %%
import tensorflow as tf

# %%
age = tf.feature_column.numeric_column('housingMedianAge')
rooms = tf.feature_column.numeric_column('totalRooms')
bedrooms = tf.feature_column.numeric_column('totalBedrooms')
pop = tf.feature_column.numeric_column('population')
households = tf.feature_column.numeric_column('households')
income = tf.feature_column.numeric_column('medianIncome')

# %%
feat_cols = [age,rooms,bedrooms,pop,households,income]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=Y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
model = tf.estimator.DNNRegressor(hidden_units=[6,6,6],feature_columns=feat_cols)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpkif26p7j
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpkif26p7j', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %%
model.train(input_fn=input_func, steps=25000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpkif26p7j/model.ckpt.
# INFO:tensorflow:loss = 682136000000.0, step = 1
# INFO:tensorflow:global_step/sec: 261.214
# INFO:tensorflow:loss = 534378500000.0, step = 101 (0.405 sec)
# INFO:tensorflow:global_step/sec: 325.212
# INFO:tensorflow:loss = 812648240000.0, step = 201 (0.288 sec)
# INFO:tensorflow:global_step/sec: 330.825
# INFO:tensorflow:loss = 547343860000.0, step = 301 (0.309 sec)
# INFO:tensorflow:global_step/sec: 310.699
# INFO:tensorflow:loss = 358069000000.0, step = 401 (0.315 sec)
# INFO:tensorflow:global_step/sec: 322.997
# INFO:tensorflow:loss = 316539200000.0, step = 501 (0.321 sec)
# INFO:tensorflow:global_step/sec: 282.582
# ...

# %%
predict_input_func= tf.estimator.inputs.pandas_input_fn(x=x_test,batch_size=10,num_epochs=1,shuffle=False)

# %%
pred_gen = model.predict(predict_input_func)

# %%
predictions = list(pred_gen)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpkif26p7j/model.ckpt-25000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
predictions
# Out:
# [{'predictions': array([233835.97], dtype=float32)},
#  {'predictions': array([295564.], dtype=float32)},
#  {'predictions': array([216905.05], dtype=float32)},
#  {'predictions': array([186242.98], dtype=float32)},
#  {'predictions': array([267501.12], dtype=float32)},
#  {'predictions': array([202029.1], dtype=float32)},
#  {'predictions': array([227851.56], dtype=float32)},
#  {'predictions': array([207571.56], dtype=float32)},
#  {'predictions': array([216075.27], dtype=float32)},
#  {'predictions': array([187351.45], dtype=float32)},
#  {'predictions': array([207147.78], dtype=float32)},
#  {'predictions': array([226862.66], dtype=float32)},
#  {'predictions': array([194460.33], dtype=float32)},
#  {'predictions': array([179816.9], dtype=float32)},
#  {'predictions': array([259165.36], dtype=float32)},
#  {'predictions': array([178010.17], dtype=float32)},
#  {'predictions': array([202845.98], dtype=float32)},
#  {'predictions': array([188586.56], dtype=float32)},
# ...

# %%
final_pre = []
for pred in predictions:
  final_pre.append(pred['predictions'])

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,final_pre)**0.5
# Out:
# 101358.3524498996
